# %%
pip install requests beautifulsoup4 nltk
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('words')
import nltk
from nltk.corpus import stopwords, wordnet
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
import requests
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import re
from nltk.corpus import words

english_words = set(words.words())

# Step 1: Get HTML from URL
def get_html_from_url(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        return None

# Step 2: Extract text from HTML
def extract_text_from_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    text = soup.get_text()
    return text

# Step 3: Text preprocessing
def preprocess_text(text):
    # Remove non-alphanumeric characters
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Removing words that have numbers in them
    text = re.sub(r'\w\d\w', '', text)

    # Removing digits
    text = re.sub(r'[0-9]+', '', text)

    # Convert to lowercase
    text = text.lower()

    # Tokenization
    words = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]

    # Stemming
    porter_stemmer = PorterStemmer()
    words = [porter_stemmer.stem(word) for word in words]
      # Filter out words that have no meaning in WordNet
    words = [word for word in words if wordnet.synsets(word)]
    words = [word for word in words if len(word) > 2]

    return words

# Step 4: Get unique words
def get_unique_words(words):
    return set(words)

# Example usage
url = "http://drshiple-courses.weebly.com/autonomous-multiagent-systems.html"
html = get_html_from_url(url)

if html:
    text = extract_text_from_html(html)
    preprocessed_words = preprocess_text(text)
    unique_words = get_unique_words(preprocessed_words)




    print("Original Text:")
    print(text)

    print("\nPreprocessed Words:")
    print(preprocessed_words)

    print("\nUnique Words:")
    print(unique_words)
    print(len(unique_words))

else:
    print(f"Failed to fetch HTML from {url}")
# Out:
# Original Text:
#
#
#
# autonomous-multiagent-systems.html - Dr. Shiple Courses
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Dr. Shiple Courses
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Home
#
#
#
#
# 				Academic courses
#
#
#
#
#
#
# 			HTI
# 		>
#
#
#
#
#
#
# 			Microelectronic Circuits
#
#
#
#
#
#
# 			Electronics 3
#
#
#
#
#
#
# 			Advanced Electronic Circuits
#
#
#
#
#
#
# 			Shaping Circuits
#
#
#
#
#
#
# 			Switching Circuits
#
#
#
#
#
#
# 			Wave Shaping
#
#
#
#
#
#
# 			Microprocessor Architectures
#
#
#
#
#
#
# 			Advanced Microprocessor
#
#
#
#
#
#
# 			Computer Interfacing
#
#
#
#
#
#
#
#
#
# 			MIU
# 		>
#
#
#
#
#
#
# 			Selected Topics in Electronics
#
#
#
#
#
#
# 			Fundamental Tools in EE
#
#
#
#
#
#
#
#
#
# 			Cairo Uni.
# 		>
#
#
#
#
#
#
# 			Autonomous Multiagent Systems
#
#
#
#
#
#
# 			Intelligent Autonomous Robotics
#
#
#
#
#
#
# 			Electronics I
#
#
#
#
#
#
#
#
#
# 			NILE uni.
# 		>
#
#
#
#
#
#
# 			Machine Learning
#
#
#
#
#
#
#
#
#
# 			MUST
# 		>
#
#
#
#
#
#
# 			Operating Systems II
#
#
#
#
#
#
#
#
#
#
#
# 				Scientific courses
#
#
#
#
#
#
# 			VHDL Flow
# 		>
#
#
#
#
#
#
# 			VHDL Foundation Course
#
#
#
#
#
#
# 			VHDL Comprehensive course
#
#
#
#
#
#
# 			VHDL Advanced course
#
#
#
#
#
#
#
#
#
# 			Cryptography with Python
#
#
#
#
#
#
# 			Embedded Systems
# 		>
#
#
#
#
#
#
# 			Embedded C Programming
#
#
#
#
#
#
# 			Automotive Communication Protocols
#
#
#
#
#
#
# 			LabVIEW
#
#
#
#
#
#
#
#
#
# 			PCB Design and manufacture
#
#
#
#
#
#
# 			Robotics
#
#
#
#
#
#
# 			Beginner Courses
# 		>
#
#
#
#
#
#
# 			الدوائر اللإلكترونية للمبتدئين
#
#
#
#
#
#
# 			الدوائر المنطقية للمبتدئين
#
#
#
#
#
#
# 			الاردينو باللغة العربية
#
#
#
#
#
#
# 			الدوائر  التماثلية
#
#
#
#
#
#
# 			الشبكات بين المعالجات
#
#
#
#
#
#
#
#
#
#
#
# 				Micro Car Rally
#
#
#
#
# 				Seminars and workshops
#
#
#
#
#
#
# 			Research projects
#
#
#
#
#
#
#
#
# 				Read With Me
#
#
#
#
# 				Contact
#
#
#
#
# 				About
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Searching in complex environment and Game theory lectures are uploaded - an interesting resource also is added - the model answer of midterm exam is uploaded too
#
#
#
#
#
#
#
# Autonomous Multiagent Systems
#
#
#
#
#
# ﻿    To provide information of the recent trends in programmable logic, Distributed data processing.   ﻿
#
#
#
#
# 12/2/2023
#  Welcome to the start of the spring 2023 semester
#
# 11/3/2023
# Search algorithm lecture
#
# 20/3/2023
# "Search In Complex Environments" is uploaded"
#
# 22/4/2023
#  Searching in complex environment and Game theory lectures are uploaded - an interesting resource also is added - the model answer of midterm exam is uploaded too
#
# <
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Teaching Assistant
#
#
#
#
#
#
#
#
#
# Course Code
#
#
#
#
# AI314
#
#
#
#
# Academic Level
#
#
#
#
# Bachelor
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Resources
#
#
#
#
#
#
# week
#
#
# Topic
#
#
# Comments
#
#
#
#
# 1
#
#
# Introduction
#
#
#
#
#
#
#
# 2
#
#
# Architectures
#   For Intelligent Agents
#
#
#
#
#
#
#
# 3
#
#
# Solving
#   Problems By Searching
#
#
#
#
#
#
#
# 4
#
#
# Searching Algorithms
#
#
#
#
#
#
#
# 5
#
#
# Search In
#   Complex Environments
#
#
#
#
#
#
#
# 6
#
#
# MIDTERM
#
#
#
#
#
#
#
# 7
#
#
# Search with Nondeterministic
#   Actions
#
#
#
#
#
#
#
# 8
#
#
# Game Theory and Alpha-Beta Tree
#   Search Alpha
#
#
#
#
#
#
#
# 9
#
#
# Monte Carlo Tree Search and
#   Stochastic Games
#
#
#
#
#
#
#
# 10
#
#
# Agent Communication
#
#
#
#
#
#
#
# 11
#
#
# Negotiation and Bargaining
#
#
#
#
#
#
#
#
#
#
#
#
# Exams and Assignments
#
#
#
#
#
#
# #
#
#
# ITEM
#
#
# Exam
#
#
#
#
# 1
#
#
# Midterm 2023
#
#
# pdf
#
#
#
#
# 2
#
#
# Quiz version 1
#
#
# pdf
#
#
#
#
# 3
#
#
# Quiz version 2
#
#
# pdf
#
#
#
#
# 4
#
#
# Quiz version 3
#
#
# pdf
#
#
#
#
#
#
#
#
# Resources
#
#
#
#
#
#
# #
#
#
# ITEM
#
#
# Link
#
#
#
#
# 1
#
#
# AlphaGo
#
#
# YouTube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Powered by
#
# Create your own unique website with customizable templates.
#
# Get Started
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preprocessed Words:
# ['home', 'circuit', 'electron', 'electron', 'circuit', 'shape', 'circuit', 'switch', 'circuit', 'wave', 'shape', 'microprocessor', 'microprocessor', 'select', 'topic', 'electron', 'fundament', 'tool', 'cairo', 'system', 'robot', 'electron', 'nile', 'learn', 'must', 'system', 'flow', 'python', 'embed', 'system', 'embed', 'program', 'protocol', 'design', 'robot', 'micro', 'car', 'seminar', 'workshop', 'research', 'project', 'read', 'contact', 'search', 'complex', 'environ', 'game', 'upload', 'interest', 'also', 'model', 'answer', 'midterm', 'exam', 'upload', 'system', 'inform', 'recent', 'trend', 'logic', 'data', 'process', 'start', 'spring', 'search', 'algorithm', 'search', 'complex', 'environ', 'upload', 'search', 'complex', 'environ', 'game', 'upload', 'interest', 'also', 'model', 'answer', 'midterm', 'exam', 'upload', 'teach', 'assist', 'code', 'level', 'bachelor', 'week', 'topic', 'comment', 'agent', 'problem', 'search', 'search', 'algorithm', 'search', 'complex', 'environ', 'midterm', 'search', 'action', 'game', 'tree', 'search', 'alpha', 'tree', 'search', 'game', 'agent', 'bargain', 'exam', 'assign', 'item', 'exam', 'midterm', 'quiz', 'version', 'quiz', 'version', 'quiz', 'version', 'item', 'link', 'power', 'get', 'start']
#
# Unique Words:
# {'environ', 'tree', 'start', 'alpha', 'recent', 'answer', 'shape', 'assist', 'version', 'embed', 'exam', 'item', 'micro', 'quiz', 'algorithm', 'research', 'program', 'fundament', 'car', 'complex', 'action', 'bargain', 'circuit', 'microprocessor', 'trend', 'agent', 'learn', 'model', 'link', 'week', 'cairo', 'upload', 'select', 'wave', 'switch', 'also', 'nile', 'midterm', 'comment', 'flow', 'tool', 'design', 'get', 'workshop', 'home', 'code', 'search', 'system', 'teach', 'contact', 'interest', 'power', 'electron', 'process', 'level', 'logic', 'protocol', 'seminar', 'project', 'robot', 'topic', 'must', 'spring', 'python', 'bachelor', 'game', 'inform', 'problem', 'data', 'read', 'assign'}
# 71
